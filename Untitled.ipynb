# %%
import sys

sys.path.insert(0,r'/home/elkin/Documents/Facenet')

import main_recognition
from main_recognition import Recognition, precision, BD, data_preprocess, train_main

valor = precision()
print(p)

while True:
    
    if valor > 0.8:
        registro = True
        print("el registro es:", registro)
        break
    else:
        registro = False
        BD()
        data_preprocess()
        train_main.py()
        precision()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c62c0c821c22> in <module>
#       3 sys.path.insert(0,r'/home/elkin/Documents/Facenet')
#       4
# ----> 5 import main_recognition
#       6 from main_recognition import Recognition, precision, BD, data_preprocess, train_main
#       7
#
# ~/Documents/Facenet/main_recognition.py in <module>
#      21 import sys
#      22 from pymongo import MongoClient
# ---> 23 import easygui
#      24 import uuid
#      25 from preprocess import preprocesses
#
# ModuleNotFoundError: No module named 'easygui'

# %%
conda install -c achennu easygui
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# Examining python:   5%|█▏                      | 1/21 [00:00<00:00, 6374.32it/s]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python=3.7:   0%|      | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python[version='>=3.7,<3.8.0a0']:  50%|▌| 1/2 [00:00<00:00, 5667.98it/s]
#
#
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python=3.7:   0%|      | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python=2.7:  33%|▎| 1/3 [00:00<00:00, 3930.93it/s]
#
# Finding shortest conflict path for python[version='>=2.7,<2.8.0a0']:  67%|▋| 2/3 [00:00<00:00, 4415.06it/s]
#
#
# Examining wheel:  10%|██▍                       | 2/21 [00:00<00:00, 305.58it/s]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for wheel:   0%|           | 0/1 [00:00<?, ?it/s]
#
#
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for wheel:   0%|           | 0/1 [00:00<?, ?it/s]|
#
#
# Comparing specs that have this dependency: 100%|██| 2/2 [00:00<00:00, 14.19it/s]
# Examining pip:  52%|██████████████▋             | 11/21 [00:00<00:00, 27.01it/s]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for pip:   0%|             | 0/1 [00:00<?, ?it/s]
#
#
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for pip:   0%|             | 0/1 [00:00<?, ?it/s]
#
#
# Examining setuptools:  62%|█████████████        | 13/21 [00:00<00:00, 27.01it/s]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools:   0%|      | 0/1 [00:00<?, ?it/s]
#
#
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools:   0%|      | 0/1 [00:00<?, ?it/s]
#
#
# Comparing specs that have this dependency: 100%|██| 2/2 [00:00<00:00, 14.19it/s]
# Examining certifi:  76%|██████████████████▎     | 16/21 [00:00<00:00, 32.95it/s]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.9.26']:   0%| | 0/3 [00:00<?, ?it/s]\
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  33%|▎| 1/3 [00:00<00:00,  9.62it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  67%|▋| 2/3 [00:00<00:00, 19.21it/s]
#
# Finding shortest conflict path for ca-certificates:  67%|▋| 2/3 [00:00<00:00, 19.21it/s]
#
# Finding shortest conflict path for ca-certificates: 100%|█| 3/3 [00:00<00:00, 14.94it/s]|
#
#
# Comparing specs that have this dependency:  50%|█ | 1/2 [00:00<00:00,  4.32it/s]
#
# Finding conflict paths:   0%|                             | 0/4 [00:00<?, ?it/s]
#
# Finding shortest conflict path for certifi:   0%|         | 0/4 [00:00<?, ?it/s]-
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  25%|▎| 1/4 [00:00<00:00,  3.96it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  50%|▌| 2/4 [00:00<00:00,  7.91it/s]|
#
# Finding shortest conflict path for ca-certificates:  50%|▌| 2/4 [00:00<00:00,  7.91it/s]
#
# Finding shortest conflict path for ca-certificates:  75%|▊| 3/4 [00:00<00:00,  6.11it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.9.26']:  75%|▊| 3/4 [00:00<00:00,  6.11it/s]\
#
#
# Comparing specs that have this dependency: 100%|██| 2/2 [00:00<00:00,  2.01it/s]
#                                                                                 ailed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - easygui -> python=2.7
#
# Your python: python=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
#
#
# Package certifi conflicts for:
# easygui -> python=2.7 -> pip -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# python=3.7 -> pip -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# Package ca-certificates conflicts for:
# easygui -> python=2.7 -> ca-certificates
# python=3.7 -> openssl[version='>=1.1.1a,<1.1.2a'] -> ca-certificates
# Package setuptools conflicts for:
# easygui -> python=2.7 -> pip -> setuptools
# python=3.7 -> pip -> setuptools
# Package pip conflicts for:
# python=3.7 -> pip
# easygui -> python=2.7 -> pip
# Package wheel conflicts for:
# python=3.7 -> pip -> wheel
# easygui -> python=2.7 -> pip -> wheel
#
#
# Note: you may need to restart the kernel to use updated packages.
