# %%
import sys

sys.path.insert(0,r'/home/elkin/Documents/Facenet')

import main_recognition
from main_recognition import Recognition, precision, BD, data_preprocess, train_main

valor = precision()
print("La precisión es: ",valor)

while True:
    
    if valor > 0.8:
        registro = True
        print("el registro es:", registro)
        break
    else:
        registro = False
        BD()
        data_preprocess()
        train_main.py()
        precision()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0221 14:55:30.494224 139877108074304 deprecation_wrapper.py:119] From /home/elkin/Documents/Facenet/main_recognition.py:43: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# W0221 14:55:30.497425 139877108074304 deprecation_wrapper.py:119] From /home/elkin/Documents/Facenet/main_recognition.py:44: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0221 14:55:30.500013 139877108074304 deprecation_wrapper.py:119] From /home/elkin/Documents/Facenet/main_recognition.py:44: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0221 14:55:30.796833 139877108074304 deprecation_wrapper.py:119] From /home/elkin/Documents/Facenet/detect_face.py:280: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
conda install -c achennu easygui
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# ...
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools:   0%|      | 0/1 [00:00<?, ?it/s]-
#
#
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools:   0%|      | 0/1 [00:00<?, ?it/s]
#
#
# ...
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# ...

# %%
pip install easygui
# Out:
# ...
#      |████████████████████████████████| 92kB 14kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
